# %% [markdown]
# <a href="https://colab.research.google.com/github/PratyushKakkar/Exploratory-Data-Analysis/blob/main/CA1_Data_Sci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Libraries

# %%
import pandas as pd  # Data Manipulation and Analysis
import numpy as np  # Numerical Computing
import matplotlib.pyplot as plt  # Data Visualization and Plotting
import seaborn as sns  # Statistical Sata Visualization

# %% [markdown]
# Loading the Data from the machine as a CSV
